# %%
import streamlit as st
import folium
from streamlit_folium import st_folium
from geopy.geocoders import Nominatim
import osmnx as ox
import geopandas as gpd
from shapely.geometry import Point
import pandas as pd
import plotly.express as px
from folium import GeoJson, GeoJsonTooltip
import xlrd
pd.set_option('display.max_rows', None)
# Out:
# 2025-11-01 20:41:20.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
geolocator = Nominatim(user_agent="Navigator")

@st.cache_data(show_spinner=True, show_time = True)
def geocode_address(address):
    geolocator = Nominatim(user_agent="Navigator")
    return geolocator.geocode(address)

@st.cache_data(show_spinner=True, show_time = True)
def get_osm_features(lat, lon, tags, dist):
    return ox.features_from_point((lat, lon), tags=tags, dist=dist)

@st.cache_data
def load_pie_index(sheet):
    df = pd.read_excel("OSM features.xls", sheet_name=sheet)
    df = df.dropna(subset=["key", "value"])
    df["key"] = df["key"].astype(str).str.strip()
    df["value"] = df["value"].astype(str).str.strip()
    return df

    
def clip_to_circle(gdf, lat, lon, radius):
    if gdf.crs is None:
        gdf = gdf.set_crs(4326)
    proj_crs = gdf.estimate_utm_crs()
    gdf_proj = gdf.to_crs(proj_crs)
    center = Point(lon, lat)
    circle = gpd.GeoSeries([center], crs=4326).to_crs(proj_crs).buffer(radius)
    return gpd.clip(gdf_proj, circle).to_crs(4326)


def melt_tags(gdf, tag_keys):
    # keep onlt keys that exist in gdf
    tag_keys = [k for k in tag_keys if k in gdf.columns]
    if not tag_keys:
        raise ValueError("None of the provided tag_keys exist in the GeoDataFrame.")

    melted = (
        gdf[tag_keys]
        .stack()
        .reset_index()
        .rename(columns={"level_2": "key", 0: "value"})
    )
    melted = melted.merge(gdf.reset_index()[["id", "geometry"]], on="id")
    melted = melted.drop(columns="element")
    melted = gpd.GeoDataFrame(melted, geometry="geometry", crs=gdf.crs)
    return melted
# Out:
# 2025-11-01 20:41:22.821 No runtime found, using MemoryCacheStorageManager
# 2025-11-01 20:41:22.822 No runtime found, using MemoryCacheStorageManager
# 2025-11-01 20:41:22.824 No runtime found, using MemoryCacheStorageManager

# %%
ms_index  = load_pie_index("Multiselect")
ms_index = ms_index[ms_index['Multiselect'].notna()]
ms_index
# Out:
# 2025-11-01 20:41:22.833 No runtime found, using MemoryCacheStorageManager
# 2025-11-01 20:41:22.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.119
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\anita\anaconda3\envs\environment\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-01 20:41:23.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#          Category               Multiselect                   subcategory  \
# 0   Food & Drinks                       bar                   substenance
# 1   Food & Drinks                      cafe                   substenance
# 2   Food & Drinks                 fast food                   substenance
# 3   Food & Drinks                       bar                   substenance
# 4   Food & Drinks                restaurant                   substenance
# 5       Education                   college                     education
# 6       Education              kindergarten                     education
# 7       Education                   library                     education
# 8       Education                    school                     education
# 9       Education                university                     education
# 10      Transport              bike parking                transportation
# 11      Transport               bike repair                transportation
# 12      Transport  public transport station                transportation
# 13      Transport               car sharing                transportation
# 14      Transport       EV charging station                transportation
# 15      Transport  public transport station                transportation
# 16      Transport                   parking                transportation
# 17      Transport                   parking                transportation
# 18       Services                      bank                     financial
# 19     Healthcare                    clinic                    healthcare
# 20     Healthcare                   dentist                    healthcare
# 21     Healthcare                   doctors                    healthcare
# 22     Healthcare                  hospital                    healthcare
# 23     Healthcare                  pharmacy                    healthcare
# 24     Healthcare                veterinary                    healthcare
# 25        Leisure                    cinema  entertainment, arts, culture
# 26        Leisure         activities centre  entertainment, arts, culture
# 27        Leisure                 nightclub  entertainment, arts, culture
# 28        Leisure         activities centre  entertainment, arts, culture
# 29        Leisure                   theater  entertainment, arts, culture
# 30       Services             post services                public service
# 31       Services             post services                public service
# 32        Leisure                  barbecue                    facilities
# 33         Stores                    market                         other
# 34       Religion                    church                     religious
# 35       Religion                    mosque                     religious
# 36       Religion                 synagogue                     religious
# 37        Leisure                  dog park                           NaN
# 38        Leisure                       gym                           NaN
# 39        Leisure           outdoor fitness                           NaN
# 40        Leisure             horse raiding                           NaN
# 41        Leisure                  ice rink                           NaN
# 42        Leisure            nature_reserve                           NaN
# 43        Leisure                      park                           NaN
# 44        Leisure                playground                           NaN
# 45        Leisure             sports centre                           NaN
# 46        Leisure                   stadium                           NaN
# 47        Leisure             swimming area                           NaN
# 48        Leisure             swimming pool                           NaN
# 49         Stores                    bakery              Food & beverages
# 50         Stores         convenience store              Food & beverages
# 51         Stores             shopping mall                       general
# 52         Stores             shopping mall                       general
# 53         Stores               supermarket                       general
# 54       Services               hairdresser               Health & beauty
# 55       Services                   massage               Health & beauty
# 56         Stores                     books                    stationery
# 57       Services                   laundry                         other
# 58         Stores                      pets                         other
# 59       Services              pet grooming                         other
# 60      Transport  public transport station                      stations
# 61      Transport           subway entrance                      stations
# 62      Transport  public transport station                      stations
# 63      Transport  public transport station              Public transport
#
#                  key                   value       color            icon  \
# 0            amenity                     bar    darkblue           glass
# 1            amenity                    cafe       beige      mug-saucer
# 2            amenity               fast_food         NaN             NaN
# 3            amenity                     pub         NaN             NaN
# 4            amenity              restaurant      orange         cutlery
# 5            amenity                 college         NaN       education
# 6            amenity            kindergarten         NaN             NaN
# 7            amenity                 library         NaN             NaN
# 8            amenity                  school         NaN       education
# 9            amenity              university         NaN       education
# 10           amenity         bicycle_parking         NaN             NaN
# 11           amenity  bicycle_repair_station         NaN             NaN
# 12           amenity             bus_station         NaN             NaN
# 13           amenity             car_sharing         NaN             NaN
# 14           amenity        charging_station         NaN             NaN
# 15           amenity          ferry_terminal         NaN             NaN
# 16           amenity                 parking         NaN             NaN
# 17           amenity           parking_space         NaN             NaN
# 18           amenity                    bank         NaN      piggy-bank
# 19           amenity                  clinic         NaN        asterisk
# 20           amenity                 dentist         NaN        asterisk
# 21           amenity                 doctors         NaN        asterisk
# 22           amenity                hospital         NaN        asterisk
# 23           amenity                pharmacy         NaN        asterisk
# 24           amenity              veterinary         NaN        asterisk
# 25           amenity                  cinema         NaN             NaN
# 26           amenity        community_centre         NaN             NaN
# 27           amenity               nightclub         NaN             NaN
# 28           amenity           social_centre         NaN             NaN
# 29           amenity                 theatre         NaN             NaN
# 30           amenity                post_box         NaN        envelope
# 31           amenity             post_office         NaN        envelope
# 32           amenity                     bbq         NaN             NaN
# 33           amenity             marketplace         NaN           apple
# 34          building                  church         NaN             NaN
# 35          building                  mosque         NaN             NaN
# 36          building               synagogue         NaN             NaN
# 37           leisure                dog_park         NaN             NaN
# 38           leisure          fitness_centre         NaN             NaN
# 39           leisure         fitness_station         NaN             NaN
# 40           leisure            horse_riding         NaN             NaN
# 41           leisure                ice_rink         NaN             NaN
# 42           leisure          nature_reserve         NaN             NaN
# 43           leisure                    park       green  tree-deciduous
# 44           leisure              playground  lightgreen          knight
# 45           leisure           sports_centre         NaN             NaN
# 46           leisure                 stadium         NaN             NaN
# 47           leisure           swimming_area         NaN             NaN
# 48           leisure           swimming_pool         NaN             NaN
# 49              shop                  bakery    lightred  fa-bread-slice
# 50              shop             convenience         NaN             NaN
# 51              shop        department_store         NaN             NaN
# 52              shop                    mall         NaN             NaN
# 53              shop             supermarket        blue   shopping-cart
# 54              shop             hairdresser         NaN             NaN
# 55              shop                 massage         NaN             NaN
# 56              shop                   books     darkred            book
# 57              shop                 laundry         NaN             NaN
# 58              shop                     pet         NaN             NaN
# 59              shop            pet_grooming         NaN             NaN
# 60  public_transport                 station         NaN             NaN
# 61           railway         subway_entrance         NaN             NaN
# 62           railway               tram_stop         NaN             NaN
# 63  public_transport                 station         NaN             NaN
#
#                                           description
# 0   Bar is a purpose-built commercial establishmen...
# 1   Cafe is generally an informal place that offer...
# 2   Fast food restaurant (see also amenity=restaur...
# 3   A place selling beer and other alcoholic drink...
# 4   Restaurant (not fast food, see amenity=fast_fo...
# 5   Campus or buildings of an institute of Further...
# 6   For children too young for a regular school (a...
# 7   A public library (municipal, university, …) to...
# 8   School and grounds - primary, middle and secon...
# 9   A university campus: an institute of higher ed...
# 10                               Parking for bicycles
# 11  General tools for self-service bicycle repairs...
# 12    May also be tagged as public_transport=station.
# 13                                        Share a car
# 14            Charging facility for electric vehicles
# 15  Ferry terminal/stop. A place where people/cars...
# 16  Parking area for vehicles. Streets on car park...
# 17  A single parking space within a car park. Park...
# 18  Bank or credit union: a financial establishmen...
# 19  A medium-sized medical facility or health centre.
# 20                      A dentist practice / surgery.
# 21                     A doctor's practice / surgery.
# 22  A hospital providing in-patient medical treatm...
# 23  Pharmacy: a shop where a pharmacist sells medi...
# 24  A place where a veterinary surgeon, also known...
# 25  A place where films are shown (US: movie theater)
# 26  A place mostly used for local events, festivit...
# 27  A place to drink and dance (nightclub). The Ge...
# 28    A place for free and not-for-profit activities.
# 29  A theatre or opera house where live performanc...
# 30  A box for the reception of mail. Alternative m...
# 31          Post office building with postal services
# 32  BBQ or Barbecue is a permanently built grill f...
# 33  A marketplace where goods and services are tra...
# 34  A building that was built as a church. Used in...
# 35  A building errected as mosque. Used in conjunc...
# 36  A building that was built as a synagogue. Used...
# 37  A designated area, with or without a fenced bo...
# 38  Fitness centre, health club or gym with exerci...
# 39  An outdoor facility where people can practise ...
# 40  A facility where people practise horse riding,...
# 41  A place where you can skate and play bandy or ...
# 42  A protected area of importance for wildlife, f...
# 43  A park, usually in an urban (municipal) settin...
# 44  A playground: an area designed for children to...
# 45  A sports centre is a distinct facility where s...
# 46  A major sports facility with substantial tiere...
# 47  An area for swimming within a larger body of w...
# 48                 A swimming pool (water area only).
# 49                      Shop focused on selling bread
# 50  A small local shop carrying a small subset of ...
# 51  A single large store – often multiple storeys ...
# 52  A shopping mall – multiple stores under one ro...
# 53  Supermarket – a large store with groceries and...
# 54  Here you can get your hair cut, coloured, … Se...
# 55                                     A massage shop
# 56  Shop focused on selling books (for a library t...
# 57  A shop to get your normal clothes washed. Migh...
# 58  A shop for pets, animals and toys or food for ...
# 59  A shop offering grooming services for pets (mo...
# 60                   Railway passenger-only station.
# 61  The entrance to a subway station, usually goin...
# 62  A tram stop is a place where a passenger can e...
# 63  A station is an area designed to access public...

# %%
ms_cats = ms_index['Category'].unique()
ms_cats
# Out:
# array(['Food & Drinks', 'Education', 'Transport', 'Services',
#        'Healthcare', 'Leisure', 'Stores', 'Religion'], dtype=object)

# %%
address = "Skaldevägen 60"
POI_radius=500
location = geocode_address(address)
lat, lon = location.latitude, location.longitude
lat,lon
# Out:
# 2025-11-01 20:41:23.199 No runtime found, using MemoryCacheStorageManager
# 2025-11-01 20:41:23.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# (59.3285363, 17.9360367)

# %%
poi_tags = {
    "amenity": ["restaurant", "bar", "cafe"],
    "leisure": ["park", "playground"],
    "shop": ["supermarket", "bakery"]
}

# %%
ms_poi = get_osm_features(lat, lon, poi_tags, POI_radius)
ms_poi
# Out:
# 2025-11-01 20:41:23.430 No runtime found, using MemoryCacheStorageManager
# 2025-11-01 20:41:23.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-01 20:41:23.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#                                                                geometry  \
# element  id
# node     248752304                            POINT (17.92894 59.32944)
#          566435738                            POINT (17.92864 59.32886)
#          566435740                            POINT (17.92794 59.32891)
#          1512612813                           POINT (17.92822 59.32942)
#          1516347784                           POINT (17.93867 59.32884)
#          1563539320                            POINT (17.93164 59.3313)
#          4648413053                           POINT (17.93394 59.32674)
#          11975133977                          POINT (17.92904 59.32958)
#          12163401910                          POINT (17.93596 59.32807)
# relation 9680850      POLYGON ((17.93926 59.32994, 17.93969 59.32988...
# way      138575212    POLYGON ((17.92973 59.33108, 17.93072 59.33122...
#          344084533    POLYGON ((17.93969 59.32988, 17.93963 59.33031...
#          587603885    POLYGON ((17.94206 59.32469, 17.94205 59.32483...
#          678517872    POLYGON ((17.93113 59.3317, 17.93119 59.33169,...
#          680473356    POLYGON ((17.93726 59.32442, 17.93734 59.32432...
#          705102013    POLYGON ((17.93324 59.32392, 17.933 59.32385, ...
#
#                          amenity   cuisine                 name addr:city  \
# element  id
# node     248752304    restaurant     pizza     Nockeby Pizzeria       NaN
#          566435738           NaN       NaN  Coop Engströms Livs    Bromma
#          566435740          cafe       NaN       Nockeby bageri       NaN
#          1512612813   restaurant    indian              Mezbaan       NaN
#          1516347784   restaurant     pizza             Appetito       NaN
#          1563539320   restaurant     pizza  Pizzeria Red Corner       NaN
#          4648413053          NaN       NaN                  NaN       NaN
#          11975133977  restaurant  japanese         PanPan Sushi       NaN
#          12163401910         NaN       NaN           Kea Bageri       NaN
# relation 9680850             NaN       NaN                  NaN       NaN
# way      138575212           NaN       NaN                  NaN       NaN
#          344084533           NaN       NaN                  NaN       NaN
#          587603885           NaN       NaN         Virvelbacken       NaN
#          678517872           NaN       NaN            Brålunden       NaN
#          680473356           NaN       NaN         Thalialunden       NaN
#          705102013           NaN       NaN                  NaN       NaN
#
#                      addr:postcode   addr:street          alt_name brand  \
# element  id
# node     248752304             NaN           NaN               NaN   NaN
#          566435738          167 74  Nockeby Torg  Coop Nockebytorg  Coop
#          566435740             NaN           NaN               NaN   NaN
#          1512612813            NaN           NaN               NaN   NaN
#          1516347784            NaN     Västerled               NaN   NaN
#          1563539320            NaN           NaN               NaN   NaN
#          4648413053            NaN           NaN               NaN   NaN
#          11975133977           NaN           NaN               NaN   NaN
#          12163401910           NaN           NaN               NaN   NaN
# relation 9680850               NaN           NaN               NaN   NaN
# way      138575212             NaN           NaN               NaN   NaN
#          344084533             NaN           NaN               NaN   NaN
#          587603885             NaN           NaN               NaN   NaN
#          678517872             NaN           NaN               NaN   NaN
#          680473356             NaN           NaN               NaN   NaN
#          705102013             NaN           NaN               NaN   NaN
#
#                      brand:wikidata  ...         shop  \
# element  id                          ...
# node     248752304              NaN  ...          NaN
#          566435738       Q106684510  ...  supermarket
#          566435740              NaN  ...          NaN
#          1512612813             NaN  ...          NaN
#          1516347784             NaN  ...          NaN
#          1563539320             NaN  ...          NaN
#          4648413053             NaN  ...          NaN
#          11975133977            NaN  ...          NaN
#          12163401910            NaN  ...       bakery
# relation 9680850                NaN  ...          NaN
# way      138575212              NaN  ...          NaN
#          344084533              NaN  ...          NaN
#          587603885              NaN  ...          NaN
#          678517872              NaN  ...          NaN
#          680473356              NaN  ...          NaN
#          705102013              NaN  ...          NaN
#
#                                                                 website  \
# element  id
# node     248752304                                                  NaN
#          566435738    https://www.coop.se/butiker-erbjudanden/coop/c...
#          566435740                                                  NaN
#          1512612813                                                 NaN
#          1516347784                                                 NaN
#          1563539320                                                 NaN
#          4648413053                                                 NaN
#          11975133977                                                NaN
#          12163401910                                                NaN
# relation 9680850                                                    NaN
# way      138575212                                                  NaN
#          344084533                                                  NaN
#          587603885                                                  NaN
#          678517872                                                  NaN
#          680473356                                                  NaN
#          705102013                                                  NaN
#
#                      wheelchair                    email organic addr:country  \
# element  id
# node     248752304          NaN                      NaN     NaN          NaN
#          566435738          yes                      NaN     NaN          NaN
#          566435740           no  butik@nockebybageri.com     yes          NaN
#          1512612813         NaN                      NaN     NaN          NaN
#          1516347784         NaN                      NaN     NaN           SE
#          1563539320         NaN                      NaN     NaN          NaN
#          4648413053         NaN                      NaN     NaN          NaN
#          11975133977        NaN                      NaN     NaN          NaN
#          12163401910        NaN                      NaN     NaN          NaN
# relation 9680850            NaN                      NaN     NaN          NaN
# way      138575212          NaN                      NaN     NaN          NaN
#          344084533          NaN                      NaN     NaN          NaN
#          587603885          NaN                      NaN     NaN          NaN
#          678517872          NaN                      NaN     NaN          NaN
#          680473356          NaN                      NaN     NaN          NaN
#          705102013          NaN                      NaN     NaN          NaN
#
#                      addr:housenumber     leisure landuse          type
# element  id
# node     248752304                NaN         NaN     NaN           NaN
#          566435738                NaN         NaN     NaN           NaN
#          566435740                NaN         NaN     NaN           NaN
#          1512612813               NaN         NaN     NaN           NaN
#          1516347784               183         NaN     NaN           NaN
#          1563539320               NaN         NaN     NaN           NaN
#          4648413053               NaN  playground     NaN           NaN
#          11975133977              NaN         NaN     NaN           NaN
#          12163401910              NaN         NaN     NaN           NaN
# relation 9680850                  NaN        park   grass  multipolygon
# way      138575212                NaN  playground     NaN           NaN
#          344084533                NaN  playground     NaN           NaN
#          587603885                NaN        park  forest           NaN
#          678517872                NaN        park     NaN           NaN
#          680473356                NaN        park     NaN           NaN
#          705102013                NaN        park     NaN           NaN
#
# [16 rows x 22 columns]

# %%
poi_data = melt_tags(ms_poi, poi_tags.keys()).reset_index().merge(ms_poi.reset_index()[["id", "name"]], on="id").merge(ms_index[["Category", "Multiselect", "key", "value", "color", "icon"]], on=["key", "value"])
poi_data
# Out:
#     index           id      key        value  \
# 0       0    248752304  amenity   restaurant
# 1       1    566435738     shop  supermarket
# 2       2    566435740  amenity         cafe
# 3       3   1512612813  amenity   restaurant
# 4       4   1516347784  amenity   restaurant
# 5       5   1563539320  amenity   restaurant
# 6       6   4648413053  leisure   playground
# 7       7  11975133977  amenity   restaurant
# 8       8  12163401910     shop       bakery
# 9       9      9680850  leisure         park
# 10     10    138575212  leisure   playground
# 11     11    344084533  leisure   playground
# 12     12    587603885  leisure         park
# 13     13    678517872  leisure         park
# 14     14    680473356  leisure         park
# 15     15    705102013  leisure         park
#
#                                              geometry                 name  \
# 0                           POINT (17.92894 59.32944)     Nockeby Pizzeria
# 1                           POINT (17.92864 59.32886)  Coop Engströms Livs
# 2                           POINT (17.92794 59.32891)       Nockeby bageri
# 3                           POINT (17.92822 59.32942)              Mezbaan
# 4                           POINT (17.93867 59.32884)             Appetito
# 5                            POINT (17.93164 59.3313)  Pizzeria Red Corner
# 6                           POINT (17.93394 59.32674)                  NaN
# 7                           POINT (17.92904 59.32958)         PanPan Sushi
# 8                           POINT (17.93596 59.32807)           Kea Bageri
# 9   POLYGON ((17.93926 59.32994, 17.93969 59.32988...                  NaN
# 10  POLYGON ((17.92973 59.33108, 17.93072 59.33122...                  NaN
# 11  POLYGON ((17.93969 59.32988, 17.93963 59.33031...                  NaN
# 12  POLYGON ((17.94206 59.32469, 17.94205 59.32483...         Virvelbacken
# 13  POLYGON ((17.93113 59.3317, 17.93119 59.33169,...            Brålunden
# 14  POLYGON ((17.93726 59.32442, 17.93734 59.32432...         Thalialunden
# 15  POLYGON ((17.93324 59.32392, 17.933 59.32385, ...                  NaN
#
#          Category  Multiselect       color            icon
# 0   Food & Drinks   restaurant      orange         cutlery
# 1          Stores  supermarket        blue   shopping-cart
# 2   Food & Drinks         cafe       beige      mug-saucer
# 3   Food & Drinks   restaurant      orange         cutlery
# 4   Food & Drinks   restaurant      orange         cutlery
# 5   Food & Drinks   restaurant      orange         cutlery
# 6         Leisure   playground  lightgreen          knight
# 7   Food & Drinks   restaurant      orange         cutlery
# 8          Stores       bakery    lightred  fa-bread-slice
# 9         Leisure         park       green  tree-deciduous
# 10        Leisure   playground  lightgreen          knight
# 11        Leisure   playground  lightgreen          knight
# 12        Leisure         park       green  tree-deciduous
# 13        Leisure         park       green  tree-deciduous
# 14        Leisure         park       green  tree-deciduous
# 15        Leisure         park       green  tree-deciduous

# %%
poi_data.loc[poi_data['name'].isna(), 'name']="Unnamed"

# %%
poi_data
# Out:
#     index           id      key        value  \
# 0       0    248752304  amenity   restaurant
# 1       1    566435738     shop  supermarket
# 2       2    566435740  amenity         cafe
# 3       3   1512612813  amenity   restaurant
# 4       4   1516347784  amenity   restaurant
# 5       5   1563539320  amenity   restaurant
# 6       6   4648413053  leisure   playground
# 7       7  11975133977  amenity   restaurant
# 8       8  12163401910     shop       bakery
# 9       9      9680850  leisure         park
# 10     10    138575212  leisure   playground
# 11     11    344084533  leisure   playground
# 12     12    587603885  leisure         park
# 13     13    678517872  leisure         park
# 14     14    680473356  leisure         park
# 15     15    705102013  leisure         park
#
#                                              geometry                 name  \
# 0                           POINT (17.92894 59.32944)     Nockeby Pizzeria
# 1                           POINT (17.92864 59.32886)  Coop Engströms Livs
# 2                           POINT (17.92794 59.32891)       Nockeby bageri
# 3                           POINT (17.92822 59.32942)              Mezbaan
# 4                           POINT (17.93867 59.32884)             Appetito
# 5                            POINT (17.93164 59.3313)  Pizzeria Red Corner
# 6                           POINT (17.93394 59.32674)              Unnamed
# 7                           POINT (17.92904 59.32958)         PanPan Sushi
# 8                           POINT (17.93596 59.32807)           Kea Bageri
# 9   POLYGON ((17.93926 59.32994, 17.93969 59.32988...              Unnamed
# 10  POLYGON ((17.92973 59.33108, 17.93072 59.33122...              Unnamed
# 11  POLYGON ((17.93969 59.32988, 17.93963 59.33031...              Unnamed
# 12  POLYGON ((17.94206 59.32469, 17.94205 59.32483...         Virvelbacken
# 13  POLYGON ((17.93113 59.3317, 17.93119 59.33169,...            Brålunden
# 14  POLYGON ((17.93726 59.32442, 17.93734 59.32432...         Thalialunden
# 15  POLYGON ((17.93324 59.32392, 17.933 59.32385, ...              Unnamed
#
#          Category  Multiselect       color            icon
# 0   Food & Drinks   restaurant      orange         cutlery
# 1          Stores  supermarket        blue   shopping-cart
# 2   Food & Drinks         cafe       beige      mug-saucer
# 3   Food & Drinks   restaurant      orange         cutlery
# 4   Food & Drinks   restaurant      orange         cutlery
# 5   Food & Drinks   restaurant      orange         cutlery
# 6         Leisure   playground  lightgreen          knight
# 7   Food & Drinks   restaurant      orange         cutlery
# 8          Stores       bakery    lightred  fa-bread-slice
# 9         Leisure         park       green  tree-deciduous
# 10        Leisure   playground  lightgreen          knight
# 11        Leisure   playground  lightgreen          knight
# 12        Leisure         park       green  tree-deciduous
# 13        Leisure         park       green  tree-deciduous
# 14        Leisure         park       green  tree-deciduous
# 15        Leisure         park       green  tree-deciduous

# %%
m = folium.Map(location=[lat, lon], zoom_start=14)         
# Add address marker
folium.Marker([lat, lon], popup=address, icon=folium.Icon(color='red', icon='home')).add_to(m)
folium.Circle(
    location=[lat, lon],
    radius=POI_radius,  # in meters
    color='red',       
    fill=False,
    weight=2            
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42029226270e3d5d34361a41f3a362eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42029226270e3d5d34361a41f3a362eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42029226270e3d5d34361a41f3a362eb = L.map(
#                 &quot;map_42029226270e3d5d34361a41f3a362eb&quot;,
#                 {
#                     center: [59.3285363, 17.9360367],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44c8b651f294e1680a63521be32397f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44c8b651f294e1680a63521be32397f4.addTo(map_42029226270e3d5d34361a41f3a362eb);
#
#
#             var marker_a491669d9563d102771e28aa57464700 = L.marker(
#                 [59.3285363, 17.9360367],
#                 {
# }
#             ).addTo(map_42029226270e3d5d34361a41f3a362eb);
#
#
#             var icon_b40e02a9333de05c8d4679d1f6a0402b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_09d95e50b4b3a9276096bc6cf3873363 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e575ad25699b5aad5546692b8505a1ac = $(`&lt;div id=&quot;html_e575ad25699b5aad5546692b8505a1ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Skaldevägen 60&lt;/div&gt;`)[0];
#                 popup_09d95e50b4b3a9276096bc6cf3873363.setContent(html_e575ad25699b5aad5546692b8505a1ac);
#
#
#
#         marker_a491669d9563d102771e28aa57464700.bindPopup(popup_09d95e50b4b3a9276096bc6cf3873363)
#         ;
#
#
#
#
#                 marker_a491669d9563d102771e28aa57464700.setIcon(icon_b40e02a9333de05c8d4679d1f6a0402b);
#
#
#             var circle_7d47549cb957e108ed677c5330242fbe = L.circle(
#                 [59.3285363, 17.9360367],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_42029226270e3d5d34361a41f3a362eb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
poi_layer = folium.FeatureGroup(name="Points of Interest")

for idx, row in poi_data.iterrows():
                    lon_, lat_ = row.geometry.centroid.xy
                    folium.Marker(
                        location=[lat_[0], lon_[0]],
                        popup= f"<div style='font-size:12px; font-family:Arial; white-space:nowrap;'><b>{row.get("Category",'N/A').capitalize()}: </b>{row.get('Multiselect')}<br>{row.get('name', 'Unnamed')}",
                        icon=folium.Icon(
                            color=row['color'],
                            icon=row['icon'].replace("fa-", "") if str(row['icon']).startswith("fa-") else row['icon'],
                            prefix="fa" if str(row['icon']).startswith("fa-") else None
                        )
                        
                        ).add_to(poi_layer)
                         
poi_layer.add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42029226270e3d5d34361a41f3a362eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42029226270e3d5d34361a41f3a362eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42029226270e3d5d34361a41f3a362eb = L.map(
#                 &quot;map_42029226270e3d5d34361a41f3a362eb&quot;,
#                 {
#                     center: [59.3285363, 17.9360367],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44c8b651f294e1680a63521be32397f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44c8b651f294e1680a63521be32397f4.addTo(map_42029226270e3d5d34361a41f3a362eb);
#
#
#             var marker_a491669d9563d102771e28aa57464700 = L.marker(
#                 [59.3285363, 17.9360367],
#                 {
# }
#             ).addTo(map_42029226270e3d5d34361a41f3a362eb);
#
#
#             var icon_b40e02a9333de05c8d4679d1f6a0402b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_09d95e50b4b3a9276096bc6cf3873363 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e575ad25699b5aad5546692b8505a1ac = $(`&lt;div id=&quot;html_e575ad25699b5aad5546692b8505a1ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Skaldevägen 60&lt;/div&gt;`)[0];
#                 popup_09d95e50b4b3a9276096bc6cf3873363.setContent(html_e575ad25699b5aad5546692b8505a1ac);
#
#
#
#         marker_a491669d9563d102771e28aa57464700.bindPopup(popup_09d95e50b4b3a9276096bc6cf3873363)
#         ;
#
#
#
#
#                 marker_a491669d9563d102771e28aa57464700.setIcon(icon_b40e02a9333de05c8d4679d1f6a0402b);
#
#
#             var circle_7d47549cb957e108ed677c5330242fbe = L.circle(
#                 [59.3285363, 17.9360367],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_42029226270e3d5d34361a41f3a362eb);
#
#
#             tile_layer_44c8b651f294e1680a63521be32397f4.addTo(map_42029226270e3d5d34361a41f3a362eb);
#
#
#                 marker_a491669d9563d102771e28aa57464700.setIcon(icon_b40e02a9333de05c8d4679d1f6a0402b);
#
#
#             var feature_group_677dfb336a44df77995ddcfc508a731c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9ea4edfd718c0ba5a351a135fa035c6c = L.marker(
#                 [59.3294442, 17.928936],
#                 {
# }
#             ).addTo(feature_group_677dfb336a44df77995ddcfc508a731c);
#
#
#             var icon_75c09ed9131c6607af8608b7926cf4bc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9a0b85ad17bff1f98630c148a69917d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66df5f108cb71374aef3b9c0dae4e82f = $(`&lt;div id=&quot;html_66df5f108cb71374aef3b9c0dae4e82f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;font-size:12px; font-family:Arial; white-space:nowrap;&#x27;&gt;&lt;b&gt;Food &amp; drinks: &lt;/b&gt;restaurant&lt;br&gt;Nockeby Pizzeria&lt;/div&gt;`)[0];
#                 popup_9a0b85ad17bff1f98630c148a69917d1.setContent(html_66df5f108cb71374aef3b9c0dae4e82f);
#
#
#
#         marker_9ea4edfd718c0ba5a351a135fa035c6c.bindPopup(popup_9a0b85ad17bff1f98630c148a69917d1)
#         ;
#
#
#
#
#                 marker_9ea4edfd718c0ba5a351a135fa035c6c.setIcon(icon_75c09ed9131c6607af8608b7926cf4bc);
#
#
#             var marker_dac4376e7a7e581b8d1efb1f6354b45a = L.marker(
#                 [59.3288554, 17.9286351],
#                 {
# }
#             ).add
